# %% [markdown]
# # Comparing Suburbs and Identifying Clusters

# %%
from sklearn.cluster import KMeans
import pandas as pd
from sklearn.preprocessing import MinMaxScaler
from matplotlib import pyplot as plt
import seaborn as sns 
# %matplotlib inline

# %% [markdown]
# ## Data Imports

# %%
# 2018-2019 data
df = pd.read_excel(open('data/ts19individual06taxablestatusstateterritorypostcode.xlsx', 'rb'),sheet_name='Table 6A', skiprows=1)

# %%
df = df.dropna()
df.head()
# Out:
#   Taxable status State/ Territory1 Postcode  Number of individuals\nno.  \
# 0    Non Taxable               ACT     2600                        1050
# 1    Non Taxable               ACT     2601                        1173
# 2    Non Taxable               ACT     2602                        4194
# 3    Non Taxable               ACT     2603                        1060
# 4    Non Taxable               ACT     2604                        1224
#
#    Taxable income or loss3\nno.  Taxable income or loss3\n$  \
# 0                          1006                    12648452
# 1                          1136                     9900103
# 2                          4054                    52275968
# 3                          1003                    12662531
# 4                          1176                    15351889
#
#    Tax on taxable income\nno.  Tax on taxable income\n$  Medicare levy\nno.  \
# 0                         259                    610116                  13
# 1                         154                    176445                   3
# 2                        1182                   1362902                  19
# 3                         302                    485408                   8
# 4                         353                    503655                  20
#
#    Medicare levy\n$  ...  Low income tax offset\n$  \
# 0             21049  ...                     59971
# 1              6188  ...                     36461
# 2             11577  ...                    265181
# 3              9183  ...                     68818
# 4             16766  ...                     77744
#
#    Low and middle income tax offset\nno.  Low and middle income tax offset\n$  \
# 0                                     95                                22502
# 1                                     44                                 8931
# 2                                    404                                99011
# 3                                    114                                27038
# 4                                    116                                31954
#
#    People with private health insurance\nno.  \
# 0                                        742
# 1                                        377
# 2                                       2175
# 3                                        682
# 4                                        685
#
#    Private health insurance - your Australian Government rebate received\nno.  \
# 0                                                468
# 1                                                127
# 2                                               1294
# 3                                                418
# 4                                                448
#
#    Private health insurance - your Australian Government rebate received\n$  \
# 0                                             430084
# 1                                              77225
# 2                                             884597
# 3                                             346810
# 4                                             332876
#
#    Private health insurance rebate\nno.  Private health insurance rebate\n$  \
# 0                                    62                               34128
# 1                                    30                               10380
# 2                                   172                               60678
# 3                                    46                               20473
# 4                                    65                               29331
#
#    Excess private health reduction or refund (rebate reduced)\nno.  \
# 0                                                 53
# 1                                                  7
# 2                                                123
# 3                                                 55
# 4                                                 65
#
#    Excess private health reduction or refund (rebate reduced)\n$
# 0                                              25386
# 1                                               2297
# 2                                              42080
# 3                                              26914
# 4                                              18541
#
# [5 rows x 159 columns]

# %% [markdown]
# ## NSW Dataframe

# %%
df_nsw = df[df['State/ Territory1'] == 'NSW']
df_nsw
# Out:
#      Taxable status State/ Territory1   Postcode  Number of individuals\nno.  \
# 29      Non Taxable               NSW       1225                          10
# 30      Non Taxable               NSW       1230                          20
# 31      Non Taxable               NSW       1235                          22
# 32      Non Taxable               NSW       1240                          21
# 33      Non Taxable               NSW       1335                          14
# ...             ...               ...        ...                         ...
# 3347        Taxable               NSW       2879                         174
# 3348        Taxable               NSW       2880                        6805
# 3349        Taxable               NSW       2898                         249
# 3350        Taxable               NSW       2899                         858
# 3351        Taxable               NSW  NSW other                        2828
#
#       Taxable income or loss3\nno.  Taxable income or loss3\n$  \
# 29                              10                     -429822
# 30                              19                       64076
# 31                              19                      -60906
# 32                              18                       41732
# 33                              13                       38233
# ...                            ...                         ...
# 3347                           174                    12867368
# 3348                          6805                   485162220
# 3349                           249                    19243790
# 3350                           858                    49192318
# 3351                          2828                   296892493
#
#       Tax on taxable income\nno.  Tax on taxable income\n$  \
# 29                             1                       993
# 30                             7                      5519
# 31                             4                      3375
# 32                             4                      1584
# 33                             2                      1583
# ...                          ...                       ...
# 3347                         174                   2944698
# 3348                        6805                 106089472
# 3349                         249                   4510219
# 3350                         858                   9132050
# 3351                        2828                  85711610
#
#       Medicare levy\nno.  Medicare levy\n$  ...  Low income tax offset\n$  \
# 29                     0                 0  ...                         0
# 30                     0                 0  ...                      1343
# 31                     0                 0  ...                       735
# 32                     0                 0  ...                      1116
# 33                     0                 0  ...                         0
# ...                  ...               ...  ...                       ...
# 3347                 166            238438  ...                     28475
# 3348                6418           9211250  ...                   1210064
# 3349                 242            372232  ...                     43626
# 3350                 829            922955  ...                    207540
# 3351                2489           5516233  ...                    436200
#
#       Low and middle income tax offset\nno.  \
# 29                                        0
# 30                                        1
# 31                                        1
# 32                                        2
# 33                                        0
# ...                                     ...
# 3347                                    157
# 3348                                   6238
# 3349                                    221
# 3350                                    823
# 3351                                   2356
#
#       Low and middle income tax offset\n$  \
# 29                                      0
# 30                                    255
# 31                                    207
# 32                                    468
# 33                                      0
# ...                                   ...
# 3347                               125730
# 3348                              4662623
# 3349                               168247
# 3350                               600466
# 3351                              1796917
#
#       People with private health insurance\nno.  \
# 29                                            5
# 30                                           12
# 31                                           10
# 32                                            6
# 33                                           10
# ...                                         ...
# 3347                                         87
# 3348                                       3989
# 3349                                        138
# 3350                                        384
# 3351                                       1600
#
#       Private health insurance - your Australian Government rebate received\nno.  \
# 29                                                    4
# 30                                                   12
# 31                                                    9
# 32                                                    6
# 33                                                    9
# ...                                                 ...
# 3347                                                 70
# 3348                                               3433
# 3349                                                119
# 3350                                                348
# 3351                                               1403
#
#       Private health insurance - your Australian Government rebate received\n$  \
# 29                                                 2184
# 30                                                12211
# 31                                                 9295
# 32                                                 3081
# 33                                                 7699
# ...                                                 ...
# 3347                                              39557
# 3348                                            2219389
# 3349                                              80073
# 3350                                             229133
# 3351                                             916333
#
#       Private health insurance rebate\nno.  \
# 29                                       1
# 30                                       1
# 31                                       1
# 32                                       0
# 33                                       1
# ...                                    ...
# 3347                                    20
# 3348                                   544
# 3349                                    11
# 3350                                    26
# 3351                                   155
#
#       Private health insurance rebate\n$  \
# 29                                   610
# 30                                    26
# 31                                    89
# 32                                     0
# 33                                     6
# ...                                  ...
# 3347                                5261
# 3348                              186337
# 3349                                5387
# 3350                               10597
# 3351                               48033
#
#       Excess private health reduction or refund (rebate reduced)\nno.  \
# 29                                                    0
# 30                                                    0
# 31                                                    0
# 32                                                    1
# 33                                                    2
# ...                                                 ...
# 3347                                                 22
# 3348                                                899
# 3349                                                 37
# 3350                                                 52
# 3351                                                497
#
#       Excess private health reduction or refund (rebate reduced)\n$
# 29                                                    0
# 30                                                    0
# 31                                                    0
# 32                                                  481
# 33                                                  619
# ...                                                 ...
# 3347                                               9282
# 3348                                             326860
# 3349                                              20797
# 3350                                              18029
# 3351                                             233498
#
# [1296 rows x 159 columns]

# %% [markdown]
# ### Taxable Income or Loss

# %%
df_nsw_taxable_income = df_nsw[['Postcode', 'Taxable income or loss3\n$']].copy()
df_nsw_taxable_income = df_nsw_taxable_income.rename(columns={'Taxable income or loss3\n$': 'Taxable income or loss'})
df_nsw_taxable_income = df_nsw_taxable_income[df_nsw_taxable_income['Postcode'] != 'NSW other']
df_nsw_taxable_income
# Out:
#      Postcode  Taxable income or loss
# 29       1225                 -429822
# 30       1230                   64076
# 31       1235                  -60906
# 32       1240                   41732
# 33       1335                   38233
# ...       ...                     ...
# 3346     2878                 7564444
# 3347     2879                12867368
# 3348     2880               485162220
# 3349     2898                19243790
# 3350     2899                49192318
#
# [1294 rows x 2 columns]

# %%
sse = []
k_rng = range(1,10)
for k in k_rng:
    km = KMeans(n_clusters=k)
    km.fit(df_nsw_taxable_income)
    sse.append(km.inertia_)

# %%
plt.xlabel('K')
plt.ylabel('Sum of squared error')
plt.plot(k_rng,sse)

# %%
km = KMeans(n_clusters=4)
yp = km.fit_predict(df_nsw_taxable_income)

df_nsw_taxable_income['cluster'] = yp

df1 = df_nsw_taxable_income[df_nsw_taxable_income.cluster==0]
df2 = df_nsw_taxable_income[df_nsw_taxable_income.cluster==1]
df3 = df_nsw_taxable_income[df_nsw_taxable_income.cluster==2]
df4 = df_nsw_taxable_income[df_nsw_taxable_income.cluster==3]

# %%
plt.title("NSW Postcode Clusters Based on Taxable Income")
plt.xlabel("Postcode")
plt.ylabel("Taxable Income or Loss")

plt.scatter(df1['Postcode'],df1['Taxable income or loss'],color='blue')
plt.scatter(df2['Postcode'],df2['Taxable income or loss'],color='green')
plt.scatter(df3['Postcode'],df3['Taxable income or loss'],color='yellow')
plt.scatter(df4['Postcode'],df4['Taxable income or loss'],color='red')

# %% [markdown]
# ### Salary/Wages

# %%
df_nsw_salary_wages = df_nsw[['Postcode', 'Salary or wages\n$']].copy()
df_nsw_salary_wages = df_nsw_salary_wages.rename(columns={'Salary or wages\n$': 'Salary/Wages'})
df_nsw_salary_wages = df_nsw_salary_wages[df_nsw_salary_wages['Postcode'] != 'NSW other']
df_nsw_salary_wages
# Out:
#      Postcode  Salary/Wages
# 29       1225        332606
# 30       1230         53802
# 31       1235        397048
# 32       1240        106406
# 33       1335         19427
# ...       ...           ...
# 3346     2878       4407678
# 3347     2879       9517111
# 3348     2880     428141886
# 3349     2898      12343083
# 3350     2899      38277443
#
# [1294 rows x 2 columns]

# %%
sse = []
k_rng = range(1,10)
for k in k_rng:
    km = KMeans(n_clusters=k)
    km.fit(df_nsw_taxable_income)
    sse.append(km.inertia_)

# %%
plt.xlabel('K')
plt.ylabel('Sum of squared error')
plt.plot(k_rng,sse)

# %%
km = KMeans(n_clusters=4)
yp = km.fit_predict(df_nsw_salary_wages)

df_nsw_salary_wages['cluster'] = yp

df1 = df_nsw_salary_wages[df_nsw_salary_wages.cluster==0]
df2 = df_nsw_salary_wages[df_nsw_salary_wages.cluster==1]
df3 = df_nsw_salary_wages[df_nsw_salary_wages.cluster==2]
df4 = df_nsw_salary_wages[df_nsw_salary_wages.cluster==3]

# %%
plt.title("NSW Postcode Clusters Based on Salary/Wages")
plt.xlabel("Postcode")
plt.ylabel("Salary/Wages")

plt.scatter(df1['Postcode'],df1['Salary/Wages'],color='blue')
plt.scatter(df2['Postcode'],df2['Salary/Wages'],color='green')
plt.scatter(df3['Postcode'],df3['Salary/Wages'],color='yellow')
plt.scatter(df4['Postcode'],df4['Salary/Wages'],color='red')

# %% [markdown]
# ## Victoria Dataframe

# %%
df_vic = df[df['State/ Territory1'] == 'VIC']
df_vic
# Out:
#      Taxable status State/ Territory1   Postcode  Number of individuals\nno.  \
# 1605    Non Taxable               VIC       3000                        8564
# 1606    Non Taxable               VIC       3001                         492
# 1607    Non Taxable               VIC       3002                         632
# 1608    Non Taxable               VIC       3003                        1230
# 1609    Non Taxable               VIC       3004                        1900
# ...             ...               ...        ...                         ...
# 4979        Taxable               VIC       3992                         369
# 4980        Taxable               VIC       3995                        3799
# 4981        Taxable               VIC       3996                        2288
# 4982        Taxable               VIC       8007                          34
# 4983        Taxable               VIC  VIC other                        1810
#
#       Taxable income or loss3\nno.  Taxable income or loss3\n$  \
# 1605                          8020                    80423510
# 1606                           491                     1142734
# 1607                           595                     7633881
# 1608                          1161                    12594637
# 1609                          1766                    19178469
# ...                            ...                         ...
# 4979                           369                    22292399
# 4980                          3799                   226145040
# 4981                          2288                   163433473
# 4982                            34                     4121930
# 4983                          1810                   144891311
#
#       Tax on taxable income\nno.  Tax on taxable income\n$  \
# 1605                        1749                   1291913
# 1606                           9                     10081
# 1607                         166                    347141
# 1608                         274                    213688
# 1609                         461                    583456
# ...                          ...                       ...
# 4979                         369                   4369302
# 4980                        3799                  44019784
# 4981                        2288                  36221598
# 4982                          34                   1233033
# 4983                        1810                  34959792
#
#       Medicare levy\nno.  Medicare levy\n$  ...  Low income tax offset\n$  \
# 1605                  23             32704  ...                    521647
# 1606                   0                 0  ...                      1308
# 1607                   3              9109  ...                     36607
# 1608                   1              1802  ...                     71977
# 1609                  15             16452  ...                    118371
# ...                  ...               ...  ...                       ...
# 4979                 342            415326  ...                     81431
# 4980                3493           4167384  ...                    885790
# 4981                2131           3083833  ...                    441932
# 4982                  28             79352  ...                      2617
# 4983                1661           2651205  ...                    312160
#
#       Low and middle income tax offset\nno.  \
# 1605                                    679
# 1606                                      2
# 1607                                     50
# 1608                                     96
# 1609                                    174
# ...                                     ...
# 4979                                    359
# 4980                                   3592
# 4981                                   2042
# 4982                                     14
# 4983                                   1577
#
#       Low and middle income tax offset\n$  \
# 1605                               102719
# 1606                                  876
# 1607                                10556
# 1608                                14646
# 1609                                31171
# ...                                   ...
# 4979                               257267
# 4980                              2587001
# 4981                              1486464
# 4982                                 8207
# 4983                              1189934
#
#       People with private health insurance\nno.  \
# 1605                                       1590
# 1606                                         12
# 1607                                        380
# 1608                                        320
# 1609                                        906
# ...                                         ...
# 4979                                        118
# 4980                                       1229
# 4981                                       1266
# 4982                                         26
# 4983                                        983
#
#       Private health insurance - your Australian Government rebate received\nno.  \
# 1605                                                879
# 1606                                                  9
# 1607                                                285
# 1608                                                189
# 1609                                                679
# ...                                                 ...
# 4979                                                107
# 4980                                               1102
# 4981                                               1163
# 4982                                                 22
# 4983                                                871
#
#       Private health insurance - your Australian Government rebate received\n$  \
# 1605                                             531109
# 1606                                               8006
# 1607                                             253309
# 1608                                             134110
# 1609                                             593366
# ...                                                 ...
# 4979                                              57339
# 4980                                             682226
# 4981                                             804091
# 4982                                              13368
# 4983                                             554332
#
#       Private health insurance rebate\nno.  \
# 1605                                   281
# 1606                                     0
# 1607                                    52
# 1608                                    44
# 1609                                   131
# ...                                    ...
# 4979                                    11
# 4980                                   122
# 4981                                    76
# 4982                                     2
# 4983                                    81
#
#       Private health insurance rebate\n$  \
# 1605                               75488
# 1606                                   0
# 1607                               24803
# 1608                               10651
# 1609                               40348
# ...                                  ...
# 4979                                4200
# 4980                               33829
# 4981                               25450
# 4982                                 886
# 4983                               21749
#
#       Excess private health reduction or refund (rebate reduced)\nno.  \
# 1605                                                 45
# 1606                                                  0
# 1607                                                 20
# 1608                                                 18
# 1609                                                 41
# ...                                                 ...
# 4979                                                 21
# 4980                                                265
# 4981                                                341
# 4982                                                 16
# 4983                                                264
#
#       Excess private health reduction or refund (rebate reduced)\n$
# 1605                                              12490
# 1606                                                  0
# 1607                                              10025
# 1608                                               6843
# 1609                                              22525
# ...                                                 ...
# 4979                                               7182
# 4980                                             108293
# 4981                                             161286
# 4982                                               5607
# 4983                                             110365
#
# [1408 rows x 159 columns]

# %% [markdown]
# ### Taxable Income or Loss

# %%
df_vic_taxable_income = df_vic[['Postcode', 'Taxable income or loss3\n$']].copy()
df_vic_taxable_income = df_vic_taxable_income.rename(columns={'Taxable income or loss3\n$': 'Taxable income or loss'})
df_vic_taxable_income = df_vic_taxable_income[df_vic_taxable_income['Postcode'] != 'VIC other']
df_vic_taxable_income = df_vic_taxable_income[df_vic_taxable_income['Postcode'] != 8007]
df_vic_taxable_income
# Out:
#      Postcode  Taxable income or loss
# 1605     3000                80423510
# 1606     3001                 1142734
# 1607     3002                 7633881
# 1608     3003                12594637
# 1609     3004                19178469
# ...       ...                     ...
# 4977     3990                 4397267
# 4978     3991                 9608992
# 4979     3992                22292399
# 4980     3995               226145040
# 4981     3996               163433473
#
# [1404 rows x 2 columns]

# %%
sse = []
k_rng = range(1,10)
for k in k_rng:
    km = KMeans(n_clusters=k)
    km.fit(df_vic_taxable_income)
    sse.append(km.inertia_)

# %%
plt.xlabel('K')
plt.ylabel('Sum of squared error')
plt.plot(k_rng,sse)

# %%
km = KMeans(n_clusters=4)
yp = km.fit_predict(df_vic_taxable_income)

df_vic_taxable_income['cluster'] = yp

df1 = df_vic_taxable_income[df_vic_taxable_income.cluster==0]
df2 = df_vic_taxable_income[df_vic_taxable_income.cluster==1]
df3 = df_vic_taxable_income[df_vic_taxable_income.cluster==2]
df4 = df_vic_taxable_income[df_vic_taxable_income.cluster==3]
df1.head()
# Out:
#      Postcode  Taxable income or loss  cluster
# 4282     3002               508189253        0
# 4283     3003               301559603        0
# 4284     3004               698850590        0
# 4286     3008               710242196        0
# 4289     3013               760650035        0

# %%
plt.title("VIC Postcode Clusters Based on Taxable Income")
plt.xlabel("Postcode")
plt.ylabel("Taxable Income or Loss")

plt.scatter(df1['Postcode'],df1['Taxable income or loss'],color='blue')
plt.scatter(df2['Postcode'],df2['Taxable income or loss'],color='green')
plt.scatter(df3['Postcode'],df3['Taxable income or loss'],color='yellow')
plt.scatter(df4['Postcode'],df4['Taxable income or loss'],color='red')

# %% [markdown]
# ### Salary/Wages

# %%
df_vic_salary_wages = df_vic[['Postcode', 'Salary or wages\n$']].copy()
df_vic_salary_wages = df_vic_salary_wages.rename(columns={'Salary or wages\n$': 'Salary/Wages'})
df_vic_salary_wages = df_vic_salary_wages[df_vic_salary_wages['Postcode'] != 'VIC other']
df_vic_salary_wages = df_vic_salary_wages[df_vic_salary_wages['Postcode'] != 8007]
df_vic_salary_wages
# Out:
#      Postcode  Salary/Wages
# 1605     3000      66285786
# 1606     3001        102990
# 1607     3002       2974100
# 1608     3003       9137633
# 1609     3004      10707638
# ...       ...           ...
# 4977     3990       3430331
# 4978     3991       7938153
# 4979     3992      18422267
# 4980     3995     175585481
# 4981     3996     113887711
#
# [1404 rows x 2 columns]

# %%
sse = []
k_rng = range(1,10)
for k in k_rng:
    km = KMeans(n_clusters=k)
    km.fit(df_vic_taxable_income)
    sse.append(km.inertia_)

# %%
plt.xlabel('K')
plt.ylabel('Sum of squared error')
plt.plot(k_rng,sse)

# %%
km = KMeans(n_clusters=4)
yp = km.fit_predict(df_vic_salary_wages)

df_vic_salary_wages['cluster'] = yp

df1 = df_vic_salary_wages[df_vic_salary_wages.cluster==0]
df2 = df_vic_salary_wages[df_vic_salary_wages.cluster==1]
df3 = df_vic_salary_wages[df_vic_salary_wages.cluster==2]
df4 = df_vic_salary_wages[df_vic_salary_wages.cluster==3]

# %%
plt.title("VIC Postcode Clusters Based on Salary/Wages")
plt.xlabel("Postcode")
plt.ylabel("Salary/Wages")

plt.scatter(df1['Postcode'],df1['Salary/Wages'],color='blue')
plt.scatter(df2['Postcode'],df2['Salary/Wages'],color='green')
plt.scatter(df3['Postcode'],df3['Salary/Wages'],color='yellow')
plt.scatter(df4['Postcode'],df4['Salary/Wages'],color='red')

# %% [markdown]
# Range of income for all the clustered dataframes

# %%
df1.head()
# Out:
#      Postcode  Salary/Wages  cluster
# 1605     3000      66285786        0
# 1606     3001        102990        0
# 1607     3002       2974100        0
# 1608     3003       9137633        0
# 1609     3004      10707638        0

# %%
#df_vic_taxable_income.rename(columns={'Taxable income or loss3\n$': 'Taxable income or loss'})

df_combined = {'df1': df1['Salary/Wages'], 'df2': df2['Salary/Wages']}
df_combined = pd.DataFrame(data = df_combined, index=None)
df_combined.head(5)
# Out:
#             df2
# 4280  979120543
# 4285  847722961
# 4287  766666902
# 4288  895032618
# 4290  775106018

# %%
ax1 = sns.boxplot(x=df1['Salary/Wages'])

# %%
ax2 = sns.boxplot(x=df2['Salary/Wages'])

# %%
ax3 = sns.boxplot(x=df3['Salary/Wages'])

# %%
ax4 = sns.boxplot(x=df4['Salary/Wages'])
